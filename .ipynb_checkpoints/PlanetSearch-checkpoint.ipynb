# %%
# !pip install pandas
# !pip install networkx
# !pip install scipy
# Out:
# Requirement already satisfied: pandas in c:\users\kortham\appdata\local\programs\python\python310\lib\site-packages (2.0.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\kortham\appdata\local\programs\python\python310\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\kortham\appdata\local\programs\python\python310\lib\site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\kortham\appdata\local\programs\python\python310\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: numpy>=1.21.0 in c:\users\kortham\appdata\local\programs\python\python310\lib\site-packages (from pandas) (1.24.1)
# Requirement already satisfied: six>=1.5 in c:\users\kortham\appdata\local\programs\python\python310\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: networkx in c:\users\kortham\appdata\local\programs\python\python310\lib\site-packages (2.8.8)
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: scipy in c:\users\kortham\appdata\local\programs\python\python310\lib\site-packages (1.11.2)
# Requirement already satisfied: numpy<1.28.0,>=1.21.6 in c:\users\kortham\appdata\local\programs\python\python310\lib\site-packages (from scipy) (1.24.1)
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import json
import networkx as nx
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.colors import Normalize
from collections import namedtuple

G = nx.Graph()

with open('systems.json') as f:  
    data = json.load(f)
df=pd.DataFrame(data)

with open('planets.json') as f:  
    data = json.load(f)
df_planets=pd.DataFrame(data)
#print(df)

#for row in range(len(df)):
#  print(df.at[row, 'Name'])

# %%
#print(df_planets.dtypes)
# df_planets

# %%
id_to_name = {}
for index, row in df.iterrows():
    id_to_name[row["SystemId"]] = row["Name"]

naturalID_to_name = {}
for index, row in df.iterrows():
    naturalID_to_name[row["NaturalId"]] = row["Name"]

# %%
import csv

cheap_planets_nearby_2_jumps = {}
cheap_planets_nearby_1_jump = {}
for index, row in df.iterrows():
    cheap_planets_nearby_2_jumps[row["Name"]] = 0
    cheap_planets_nearby_1_jump[row["Name"]] = 0

with open("cheap_planets_nearby_system.csv", 'r') as file:
    reader = csv.reader(file)
    
    # Read and print headers
    headers = next(reader)
    #print("Headers:", headers)
    
    # Read and print data
    for row in reader:
        #print(row)
        cheap_planets_nearby_2_jumps[naturalID_to_name[row[0]]] = int(row[3])
        cheap_planets_nearby_1_jump[naturalID_to_name[row[0]]] = int(row[2])

# %%
len(cheap_planets_nearby_2_jumps)
# Out:
# 637

# %%
len(id_to_name)
# Out:
# 637

# %%
def FindSystem(name):
    for index, row in df.iterrows():
        if row["Name"] == name: #weird type stuff????
            return row # returns a dataframe, I think?

def FindPlanetsIn(systemDf):
    matches = []
    for index, row in df_planets.iterrows():
        if id_to_name[row["SystemId"]] == systemDf["Name"]:
            matches.append(row)
    return matches
        
ANT_node = "Antares I"
BEN_node = "Benten"
MOR_node = "Moria"

fullGraph = nx.Graph()
#G.from_pandas_dataframe(df)
#list(G.nodes)

# fill graph object with nodes
for index, row in df.iterrows():
    fullGraph.add_node(row["Name"])

# and connections
for index, row in df.iterrows():
    for connection in row["Connections"]:
        #print(row["Name"] + " to " + id_to_name[connection["ConnectingId"]])
        fullGraph.add_edge(row["Name"], id_to_name[connection["ConnectingId"]])
    
print("Node count " + str(fullGraph.number_of_nodes()) + " edge count: " + str(fullGraph.number_of_edges()))

# maybe we are only interested in the systems near ANT

# within N jumps of ANT
def filterWithin15ANT(systemName):
    pathLen = nx.shortest_path_length(fullGraph, ANT_node, systemName)
    # print("Distance from " + systemName + " is " + str(pathLen))
    return pathLen < 5

# planets closer to ANT than they are to other CXes
def filterCloserToANT(systemName):
    distANT = nx.shortest_path_length(fullGraph, ANT_node, systemName)
    distBEN = nx.shortest_path_length(fullGraph, BEN_node, systemName)
    distMOR = nx.shortest_path_length(fullGraph, MOR_node, systemName)
    # print("Distance from " + systemName + " is " + str(pathLen))
    return distANT <= distBEN and distANT <= distMOR

# all planets
def filterAll(systemName):
    return True


def FilterByFunction(filterPlanetFunction):
    selected_nodes = []
    for index, row in df.iterrows():
        systemName = row["Name"]
        if(filterPlanetFunction(systemName)):
            selected_nodes.append(systemName)
        
#     print("~~~~~~~~~~~~~~~~~~~")
    subGraph = fullGraph.subgraph(selected_nodes)
#     print("after filter: Node count " + str(subGraph.number_of_nodes()) + " edge count: " + str(subGraph.number_of_edges()))
    return subGraph
# Out:
# Node count 637 edge count: 838

# %%
# find game specified xy positions:
game_pos = {}
for index, row in df.iterrows():
    if row["Name"] in fullGraph.nodes():
#         print("Find pos for " + row["Name"])
        game_pos[row["Name"]] = [row["PositionX"] / 1000.0 , row["PositionY"] / 1000.0]

# %%
# find systems with nice planets.
planet_habitable = {}
planet_good_water = {}
planet_COGC = {}
planet_fertile = {}

for index, row in df_planets.iterrows():
    
    systemName = id_to_name[row["SystemId"]]
    planetName = row["PlanetName"]

    planet_habitable.setdefault(systemName, 0)
    planet_good_water.setdefault(systemName, 0)
    planet_COGC.setdefault(systemName, 0)
    planet_fertile.setdefault(systemName, 0)

    if(row["Fertility"] > -1):
#         print("Fertile: " + str(row["Fertility"]) + " on " + planetName + " in " + systemName)
        planet_fertile[systemName] = planet_fertile.get(systemName, 0) + 1

    malusCount = 0
    pressure = row["Pressure"]
    temperature = row["Temperature"]
    gravity = row["Gravity"]

    if(gravity > 2.5 or gravity < 0.25):
        malusCount += 1
    if(temperature > 75 or temperature < -25):
        malusCount += 1
    # low pressure is fine, so or pressure < 0.25 is okay!
#    if(pressure > 2.0 or pressure < 0.25 ):
#        malusCount += 1
    if(pressure > 2.0 ):
        malusCount += 1

    if(malusCount == 0):
        planet_habitable[systemName] = planet_habitable.get(systemName, 0) + 1
        #print(str(malusCount) + " for pressure " + str(pressure) + " on " + planetName)

    #filteredValue = dict(nx.single_source_shortest_path_length(G, favoredNode))

    for reso in row["Resources"]:
        #print("Planet " + planetName + " has " + str(reso))
        #water
        if reso["MaterialId"] == "ec8dbb1d3f51d89c61b6f58fdd64a7f0" \
            and reso["ResourceType"] == "LIQUID" \
            and reso["Factor"] > 0.36: 
            # ResourceType = LIQUID Factor > 0.36 (Harmonia levels)
            planet_good_water[systemName] = 1
            #print("Found water on " + planetName)


    #consider it occupied if it has a COGC
    #print(planetName + " in " + systemName + " has COGC: " + str(row["HasChamberOfCommerce"]))
    if row["HasChamberOfCommerce"]:
        planet_COGC[systemName] = planet_COGC.get(systemName, 0) + 1
        #print("Set!")

# %%
def intersection(lst1, lst2):
    lst3 = [value for value in lst1 if value in lst2]
    return lst3

def PlotGraph(G, drawFunc, s):
    #pos = game_pos
    pos = nx.kamada_kawai_layout(G, pos=game_pos)

    plt.clf()
    plt.figure(figsize=(40,40))

    print("Drawing: Node count " + str(G.number_of_nodes()) + " edge count: " + str(G.number_of_edges()))

    drawFunc(G, pos)

    label_ratio = 1.0/16.0
    pos_labels = {}
    for aNode in G.nodes():
        #Get the node's position from the layout
        x,y = pos[aNode]
        #Get the node's neighbourhood
        N = G[aNode]
        #Find the centroid of the neighbourhood. The centroid is the average of the Neighbourhood's node's x and y coordinates respectively.
        #Please note: This could be optimised further
        cx = sum(map(lambda x:pos[x][0], N)) / len(pos)
        cy = sum(map(lambda x:pos[x][1], N)) / len(pos)
        #Get the centroid's 'direction' or 'slope'. That is, the direction TOWARDS the centroid FROM aNode.
        slopeY = (y-cy)
        slopeX = (x-cx)
        #Position the label at some distance along this line. Here, the label is positioned at about 1/8th of the distance.
        pos_labels[aNode] = [x+slopeX*label_ratio, y+slopeY*label_ratio]

        #ignore all the math we did above and just offset it from the planet. 
        pos_labels[aNode] = [x + 0.01, y + 0.01]

    # pos = pos_labels
    #  "ec": "k",
    label_options = { "fc": "white", "alpha": 0.2}
    nx.draw_networkx_labels(G, pos_labels, font_size=7, bbox=label_options)

    plt.title("Prosperous Universe\nmap by Archiel\n" + s)
    plt.margins(0.0) 
    # plt.text(0.5, 0.98, s, horizontalalignment="center")
    plt.tight_layout()
    plt.show()

# %%
def drawSummary(G, pos):
    
    # draw extra nodes to create outlines and dots inside our real nodes.
    matchingKeys = [k for k,v in planet_fertile.items() if float(v) >= 1]
    f1 = intersection(G.nodes, list(matchingKeys))
    nx.draw_networkx_nodes(G, pos, node_size=410, node_shape="_", node_color='#00CC00', nodelist=f1)
    
    # draw extra nodes to create outlines and dots inside our real nodes.
    matchingKeys = [k for k,v in planet_COGC.items() if float(v) >= 1]
    f1 = intersection(G.nodes, list(matchingKeys))
    nx.draw_networkx_nodes(G, pos, node_size=210, node_color='#00FF00', nodelist=f1)

    f1 = intersection(G.nodes, list(planet_habitable.keys()))
    colorListValues = [planet_habitable[k] for k in f1]
    nx.draw(G, pos, node_size=150, with_labels=False, nodelist=f1, node_color=colorListValues, cmap="inferno")

    # blue nodes
    matchingKeys = [k for k,v in planet_good_water.items() if float(v) >= 1]
    f1 = intersection(G.nodes, list(matchingKeys))
    nx.draw_networkx_nodes(G, pos, node_size=20, node_color='#0000FF', nodelist=f1)
  
graph = FilterByFunction(filterCloserToANT)
#graph = FilterByFunction(filterAll)
s = "Green outline indicates COGC. Blue dot indicates usable quantities of water ( liquid and > Harmonia ). Color indicates number of planets that don't need a building material other than SEA or MCG"
PlotGraph(graph, drawSummary, s)
# Out:
# Drawing: Node count 226 edge count: 297

# %%
def drawFertile(G, pos):
    
    color_map = "inferno"
    # draw extra nodes to create outlines and dots inside our real nodes.
    matchingKeys = [k for k,v in planet_fertile.items() if float(v) >= 1]
    f1 = intersection(G.nodes, list(matchingKeys))
    nx.draw_networkx_nodes(G, pos, node_size=300, node_color='#00FF00', nodelist=f1)

    f1 = intersection(G.nodes, list(planet_habitable.keys()))
    colorListValues = [planet_habitable[k] for k in f1]
    nx.draw(G, pos, node_size=110, with_labels=False, nodelist=f1, node_color=colorListValues, cmap=color_map)

    plt.colorbar(plt.cm.ScalarMappable(cmap=color_map, norm=Normalize(0, max(colorListValues))), shrink=0.5)

graph = FilterByFunction(filterAll)
PlotGraph(graph, drawFertile, "Circle indicates fertile planets. Color indicates habitability.")
# Out:
# Drawing: Node count 637 edge count: 838
# C:\Users\kortham\AppData\Local\Temp\ipykernel_53584\2758826743.py:13: MatplotlibDeprecationWarning: Unable to determine Axes to steal space for Colorbar. Using gca(), but will raise in the future. Either provide the *cax* argument to use as the Axes for the Colorbar, provide the *ax* argument to steal space from it, or add *mappable* to an Axes.
#   plt.colorbar(plt.cm.ScalarMappable(cmap=color_map, norm=Normalize(0, max(colorListValues))), shrink=0.5)

# %%
def drawCheapPlanetsF(G, pos):
    
    outputDict = cheap_planets_nearby_1_jump
    color_map = "inferno"
    f1 = intersection(G.nodes, list(outputDict.keys()))
    colorListValues = [outputDict[k] for k in f1]
    nx.draw(G, pos, node_size=110, with_labels=False, nodelist=f1, node_color=colorListValues, cmap=color_map)
    plt.colorbar(plt.cm.ScalarMappable(cmap=color_map, norm=Normalize(0, max(colorListValues))), shrink=0.5)

graph = FilterByFunction(filterAll)
PlotGraph(graph, drawCheapPlanetsF, "Color ramp indicates 'cheap_planets_nearby' within 1 jump")
# Out:
# Drawing: Node count 637 edge count: 838
# C:\Users\kortham\AppData\Local\Temp\ipykernel_53584\598905447.py:8: MatplotlibDeprecationWarning: Unable to determine Axes to steal space for Colorbar. Using gca(), but will raise in the future. Either provide the *cax* argument to use as the Axes for the Colorbar, provide the *ax* argument to steal space from it, or add *mappable* to an Axes.
#   plt.colorbar(plt.cm.ScalarMappable(cmap=color_map, norm=Normalize(0, max(colorListValues))), shrink=0.5)
# C:\Users\kortham\AppData\Local\Temp\ipykernel_53584\3254807096.py:44: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()

# %%
def drawCheapPlanetsF(G, pos):
    
    outputDict = cheap_planets_nearby_2_jumps
    color_map = "inferno"
    f1 = intersection(G.nodes, list(outputDict.keys()))
    colorListValues = [outputDict[k] for k in f1]
    nx.draw(G, pos, node_size=110, with_labels=False, nodelist=f1, node_color=colorListValues, cmap=color_map)
    plt.colorbar(plt.cm.ScalarMappable(cmap=color_map, norm=Normalize(0, max(colorListValues))), shrink=0.5)

graph = FilterByFunction(filterAll)
PlotGraph(graph, drawCheapPlanetsF, "Color ramp indicates 'cheap_planets_nearby' within 2 jumps")
# Out:
# Drawing: Node count 637 edge count: 838
# C:\Users\kortham\AppData\Local\Temp\ipykernel_53584\2703298298.py:8: MatplotlibDeprecationWarning: Unable to determine Axes to steal space for Colorbar. Using gca(), but will raise in the future. Either provide the *cax* argument to use as the Axes for the Colorbar, provide the *ax* argument to steal space from it, or add *mappable* to an Axes.
#   plt.colorbar(plt.cm.ScalarMappable(cmap=color_map, norm=Normalize(0, max(colorListValues))), shrink=0.5)
# C:\Users\kortham\AppData\Local\Temp\ipykernel_53584\3254807096.py:44: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()

# %%
#cheap_planets_nearby

# %%
def to_camel_case(text):
    return text[0]+text.title()[1:].replace("-"," ").replace("_"," ")

def EvaluatePlanet(planetDf):
    pressure = planetDf["Pressure"]
    temperature = planetDf["Temperature"]
    gravity = planetDf["Gravity"]
    surface = planetDf["Surface"]

    cost = 1688
    note = ""
    if gravity > 2.5: 
        cost += 85
        note += "High Grav (BL), "
    if gravity < 0.25:
        cost += 34*7
        note += "Low Grav (MGC), "
    if temperature > 75:
        cost += 680
        note += "High Temp (TSH), "
    if temperature < -25:
        cost += 468
        note += "Low Temp (INS), "
    if pressure > 2.0:
        cost += 272
        note += "High Press (HSE), "
    if pressure < 0.25:
        cost += 23
        note += "Low Press (SEA), "
    if not(surface):
        cost += 324
        note += "Gas (AEF), "

    if planetDf["HasChamberOfCommerce"]:
        cogc = str(planetDf["COGCPrograms"][-1]["ProgramType"])
        cogc = to_camel_case(cogc.replace("ADVERTISING_", ""))
        note = "COGC: " + cogc

    if cost < 2800:
        print("  {0:<18s} HYF Base Cost: {1:<6s} {2}".format(planetDf["PlanetName"], str(cost) + "k", note ))

def SearchNear(searchSystemNode, title, rangeN):

    print("***************************")
    print("*  Searching near " + title + " (" + searchSystemNode + ")")
    print("***************************")
    # within N jumps of ANT
    def nearSystem(systemName):
        pathLen = nx.shortest_path_length(fullGraph, searchSystemNode, systemName)
        # print("Distance from " + systemName + " is " + str(pathLen))
        return pathLen < rangeN

    g2 = FilterByFunction(nearSystem)

    # // color as distance from nascent:
    filteredValue = dict(nx.single_source_shortest_path_length(g2, searchSystemNode))
    print(searchSystemNode)
    # print(filteredValue)
    return g2

def SortAndEvalPlanets(g2, searchSystemNode):
    def funcS(x):
        return nx.shortest_path_length(g2, searchSystemNode, x)
    
    sortedNodes = list(g2.nodes)
    sortedNodes.sort(key=funcS)
    # print(sortedNodes)

    for systemName in sortedNodes:
        print()
        print(f"{systemName}      Distance {nx.shortest_path_length(g2, searchSystemNode, systemName)}")
        systemDf = FindSystem(systemName)
        for planetDf in FindPlanetsIn(systemDf):
            # evaluate planet suitability:
            EvaluatePlanet(planetDf)


g2 = SearchNear("QJ-149", "Nascent", 3) #Nascent
SortAndEvalPlanets(g2, "QJ-149")

g2 = SearchNear("SE-110", "Ice Station Alpha", 3)
SortAndEvalPlanets(g2, "SE-110")

g2 = SearchNear("KW-688", "Etherwind", 3)
SortAndEvalPlanets(g2, "KW-688")
# Out:
# ***************************
# *  Searching near Nascent (QJ-149)
# ***************************
# QJ-149
#
# QJ-149      Distance 0
#   QJ-149b            HYF Base Cost: 2391k  High Temp (TSH), Low Press (SEA),
#   QJ-149d            HYF Base Cost: 2428k  Low Temp (INS), High Press (HSE),
#   QJ-149a            HYF Base Cost: 2368k  High Temp (TSH),
#   QJ-149f            HYF Base Cost: 2480k  Low Temp (INS), Gas (AEF),
#   QJ-149e            HYF Base Cost: 2428k  Low Temp (INS), High Press (HSE),
#   QJ-149g            HYF Base Cost: 2480k  Low Temp (INS), Gas (AEF),
#   Nascent            HYF Base Cost: 1688k  COGC: Resource Extraction
#
# YK-005      Distance 1
#   YK-005b            HYF Base Cost: 2640k  High Temp (TSH), High Press (HSE),
#   YK-005e            HYF Base Cost: 2480k  Low Temp (INS), Gas (AEF),
#   YK-005a            HYF Base Cost: 2368k  High Temp (TSH),
#   YK-005c            HYF Base Cost: 2428k  Low Temp (INS), High Press (HSE),
#   YK-005d            HYF Base Cost: 2156k  COGC: Resource Extraction
#
# IY-816      Distance 1
#   IY-816f            HYF Base Cost: 2480k  Low Temp (INS), Gas (AEF),
#   IY-816h            HYF Base Cost: 2565k  High Grav (BL), Low Temp (INS), Gas (AEF),
#   IY-816b            HYF Base Cost: 2640k  High Temp (TSH), High Press (HSE),
#   IY-816a            HYF Base Cost: 2640k  High Temp (TSH), High Press (HSE),
#   IY-816g            HYF Base Cost: 2480k  Low Temp (INS), Gas (AEF),
#   IY-816d            HYF Base Cost: 2179k  Low Temp (INS), Low Press (SEA),
#   IY-816e            HYF Base Cost: 2156k  Low Temp (INS),
#   IY-816c            HYF Base Cost: 1960k  COGC: Metallurgy
#
# Acetares      Distance 1
#   QJ-684f            HYF Base Cost: 2480k  Low Temp (INS), Gas (AEF),
#   QJ-684c            HYF Base Cost: 2428k  Low Temp (INS), High Press (HSE),
#   QJ-684e            HYF Base Cost: 2480k  Low Temp (INS), Gas (AEF),
#   QJ-684d            HYF Base Cost: 2428k  Low Temp (INS), High Press (HSE),
#   Lom Palanka        HYF Base Cost: 2368k  High Temp (TSH),
#   Aceland            HYF Base Cost: 1711k  COGC: Construction
#
# Antares I      Distance 2
#   ZV-307f            HYF Base Cost: 2480k  Low Temp (INS), Gas (AEF),
#   ZV-307h            HYF Base Cost: 2480k  Low Temp (INS), Gas (AEF),
#   ZV-307g            HYF Base Cost: 2480k  COGC: Fuel Refining
#   Phobos             HYF Base Cost: 1688k  COGC: Electronics
#   ZV-307b            HYF Base Cost: 2368k  COGC: Chemistry
#   Hephaestus         HYF Base Cost: 1688k  COGC: Manufacturing
#   ZV-307a            HYF Base Cost: 2391k  COGC: Electronics
#   ZV-307e            HYF Base Cost: 2428k  COGC: Manufacturing
#
# YK-266      Distance 2
#   YK-266a            HYF Base Cost: 2391k  High Temp (TSH), Low Press (SEA),
#   YK-266g            HYF Base Cost: 2480k  Low Temp (INS), Gas (AEF),
#   YK-266b            HYF Base Cost: 2391k  High Temp (TSH), Low Press (SEA),
#   YK-266j            HYF Base Cost: 2428k  Low Temp (INS), High Press (HSE),
#   YK-266i            HYF Base Cost: 2480k  Low Temp (INS), Gas (AEF),
#   YK-266c            HYF Base Cost: 1960k  High Press (HSE),
#   YK-266d            HYF Base Cost: 2428k  Low Temp (INS), High Press (HSE),
#   YK-266h            HYF Base Cost: 2480k  Low Temp (INS), Gas (AEF),
#   YK-266e            HYF Base Cost: 2179k  Low Temp (INS), Low Press (SEA),
#   YK-266f            HYF Base Cost: 2480k  Low Temp (INS), Gas (AEF),
#
# IY-028      Distance 2
#   IY-028f            HYF Base Cost: 2480k  Low Temp (INS), Gas (AEF),
#   IY-028e            HYF Base Cost: 2480k  Low Temp (INS), Gas (AEF),
#   IY-028a            HYF Base Cost: 2368k  High Temp (TSH),
#   IY-028d            HYF Base Cost: 2428k  Low Temp (INS), High Press (HSE),
#   IY-028b            HYF Base Cost: 2368k  High Temp (TSH),
#   Electronica        HYF Base Cost: 1688k  COGC: Chemistry
#
# YK-715      Distance 2
#   YK-715a            HYF Base Cost: 2640k  High Temp (TSH), High Press (HSE),
#   YK-715d            HYF Base Cost: 1960k  High Press (HSE),
#   YK-715b            HYF Base Cost: 2640k  High Temp (TSH), High Press (HSE),
#   YK-715e            HYF Base Cost: 2428k  Low Temp (INS), High Press (HSE),
#   YK-715c            HYF Base Cost: 2368k  COGC: Workforce Pioneers
#
# YK-649      Distance 2
#   YK-649a            HYF Base Cost: 2428k  Low Temp (INS), High Press (HSE),
#   YK-649e            HYF Base Cost: 2428k  Low Temp (INS), High Press (HSE),
#   YK-649d            HYF Base Cost: 2428k  Low Temp (INS), High Press (HSE),
#   YK-649c            HYF Base Cost: 2179k  Low Temp (INS), Low Press (SEA),
#   Norwick            HYF Base Cost: 1688k  COGC: Food Industries
#
# Aurum      Distance 2
#   QJ-650a            HYF Base Cost: 2640k  High Temp (TSH), High Press (HSE),
#   QJ-650b            HYF Base Cost: 2640k  High Temp (TSH), High Press (HSE),
#   QJ-650d            HYF Base Cost: 2428k  Low Temp (INS), High Press (HSE),
#   Elon               HYF Base Cost: 1711k  COGC: Chemistry
# ***************************
# *  Searching near Ice Station Alpha (SE-110)
# ***************************
# SE-110
#
# SE-110      Distance 0
#   SE-110a            HYF Base Cost: 2428k  Low Temp (INS), High Press (HSE),
#   SE-110e            HYF Base Cost: 2480k  Low Temp (INS), Gas (AEF),
#   SE-110d            HYF Base Cost: 2179k  Low Temp (INS), Low Press (SEA),
#   SE-110f            HYF Base Cost: 2565k  High Grav (BL), Low Temp (INS), Gas (AEF),
#   Ice Station Alpha  HYF Base Cost: 2428k  COGC: Resource Extraction
#   SE-110b            HYF Base Cost: 2179k  COGC: Agriculture
#
# SE-052      Distance 1
#   SE-052a            HYF Base Cost: 2179k  Low Temp (INS), Low Press (SEA),
#   SE-052c            HYF Base Cost: 2428k  Low Temp (INS), High Press (HSE),
#   SE-052b            HYF Base Cost: 2428k  Low Temp (INS), High Press (HSE),
#   SE-052d            HYF Base Cost: 2428k  Low Temp (INS), High Press (HSE),
#   SE-052e            HYF Base Cost: 2428k  Low Temp (INS), High Press (HSE),
#   SE-052f            HYF Base Cost: 2480k  Low Temp (INS), Gas (AEF),
#
# ZV-639      Distance 1
#   ZV-639e            HYF Base Cost: 2565k  High Grav (BL), Low Temp (INS), Gas (AEF),
#   ZV-639b            HYF Base Cost: 2368k  High Temp (TSH),
#   ZV-639c            HYF Base Cost: 2428k  Low Temp (INS), High Press (HSE),
#   ZV-639a            HYF Base Cost: 2391k  High Temp (TSH), Low Press (SEA),
#   ZV-639d            HYF Base Cost: 2480k  COGC: Chemistry
#
# Antares I      Distance 2
#   ZV-307f            HYF Base Cost: 2480k  Low Temp (INS), Gas (AEF),
#   ZV-307h            HYF Base Cost: 2480k  Low Temp (INS), Gas (AEF),
#   ZV-307g            HYF Base Cost: 2480k  COGC: Fuel Refining
#   Phobos             HYF Base Cost: 1688k  COGC: Electronics
#   ZV-307b            HYF Base Cost: 2368k  COGC: Chemistry
#   Hephaestus         HYF Base Cost: 1688k  COGC: Manufacturing
#   ZV-307a            HYF Base Cost: 2391k  COGC: Electronics
#   ZV-307e            HYF Base Cost: 2428k  COGC: Manufacturing
#
# SE-648      Distance 2
#   SE-648d            HYF Base Cost: 2480k  Low Temp (INS), Gas (AEF),
#   SE-648e            HYF Base Cost: 2480k  Low Temp (INS), Gas (AEF),
#   SE-648c            HYF Base Cost: 2428k  COGC: Resource Extraction
#   SE-648b            HYF Base Cost: 2156k  COGC: Resource Extraction
#   SE-648a            HYF Base Cost: 2156k  COGC: Metallurgy
# ***************************
# *  Searching near Etherwind (KW-688)
# ***************************
# KW-688
#
# KW-688      Distance 0
#   KW-688a            HYF Base Cost: 2391k  High Temp (TSH), Low Press (SEA),
#   KW-688b            HYF Base Cost: 2640k  High Temp (TSH), High Press (HSE),
#   KW-688f            HYF Base Cost: 2480k  Low Temp (INS), Gas (AEF),
#   KW-688e            HYF Base Cost: 2480k  Low Temp (INS), Gas (AEF),
#   Etherwind          HYF Base Cost: 1688k  COGC: Resource Extraction
#   KW-688d            HYF Base Cost: 2179k  COGC: Chemistry
#
# KW-602      Distance 1
#   KW-602d            HYF Base Cost: 2428k  Low Temp (INS), High Press (HSE),
#   KW-602b            HYF Base Cost: 2640k  High Temp (TSH), High Press (HSE),
#   KW-602c            HYF Base Cost: 1688k  COGC: Food Industries
#   KW-602a            HYF Base Cost: 2391k  COGC: Agriculture
#
# KW-976      Distance 1
#   KW-976b            HYF Base Cost: 2368k  High Temp (TSH),
#   KW-976a            HYF Base Cost: 2391k  High Temp (TSH), Low Press (SEA),
#   KW-976d            HYF Base Cost: 2480k  Low Temp (INS), Gas (AEF),
#   KW-976e            HYF Base Cost: 2480k  Low Temp (INS), Gas (AEF),
#   KW-976c            HYF Base Cost: 2156k  Low Temp (INS),
#
# KW-626      Distance 2
#   KW-626a            HYF Base Cost: 1960k  High Press (HSE),
#   KW-626e            HYF Base Cost: 2480k  Low Temp (INS), Gas (AEF),
#   KW-626c            HYF Base Cost: 2179k  Low Temp (INS), Low Press (SEA),
#   KW-626d            HYF Base Cost: 2428k  Low Temp (INS), High Press (HSE),
#   KW-626b            HYF Base Cost: 1960k  High Press (HSE),
#
# XH-400      Distance 2
#   XH-400a            HYF Base Cost: 2179k  Low Temp (INS), Low Press (SEA),
#   XH-400e            HYF Base Cost: 2480k  Low Temp (INS), Gas (AEF),
#   XH-400b            HYF Base Cost: 2428k  Low Temp (INS), High Press (HSE),
#   XH-400c            HYF Base Cost: 2428k  Low Temp (INS), High Press (HSE),
#   XH-400d            HYF Base Cost: 2428k  Low Temp (INS), High Press (HSE),
#
# KW-358      Distance 2
#   KW-358i            HYF Base Cost: 2428k  Low Temp (INS), High Press (HSE),
#   KW-358g            HYF Base Cost: 2480k  Low Temp (INS), Gas (AEF),
#   KW-358a            HYF Base Cost: 2428k  Low Temp (INS), High Press (HSE),
#   KW-358f            HYF Base Cost: 2480k  Low Temp (INS), Gas (AEF),
#   KW-358d            HYF Base Cost: 2428k  Low Temp (INS), High Press (HSE),
#   KW-358h            HYF Base Cost: 2480k  Low Temp (INS), Gas (AEF),
#   KW-358e            HYF Base Cost: 2480k  Low Temp (INS), Gas (AEF),
#   Giedi Prime        HYF Base Cost: 2428k  COGC: Metallurgy
#   KW-358c            HYF Base Cost: 2156k  COGC: None
#
# LS-231      Distance 2
#   LS-231a            HYF Base Cost: 2368k  High Temp (TSH),
#   LS-231c            HYF Base Cost: 1960k  High Press (HSE),
#   LS-231e            HYF Base Cost: 2480k  Low Temp (INS), Gas (AEF),
#   LS-231f            HYF Base Cost: 2565k  High Grav (BL), Low Temp (INS), Gas (AEF),
#   LS-231d            HYF Base Cost: 1960k  High Press (HSE),
#   Aratora            HYF Base Cost: 2368k  COGC: Resource Extraction

# %%
import math

#g2 = SearchNear("QJ-149", "Nascent", 3) #Nascent
#SortAndEvalPlanets(g2, "QJ-149")

def SystemDistance(systemNameA, systemNameB, min = 0, max = 100000):
    sysA = FindSystem(systemNameA)
    sysB = FindSystem(systemNameB)
#     distance = math.hypot(sysA["PositionX"] - sysB["PositionX"], sysA["PositionY"] - sysB["PositionY"], sysA["PositionZ"] - sysB["PositionZ"])
    distance = ((sysA["PositionX"] - sysB["PositionX"])**2 + (sysA["PositionY"] - sysB["PositionY"])**2 + (sysA["PositionZ"] - sysB["PositionZ"])**2)**0.5
    jumpCount = -1
    if(distance > min and distance < max):
        jumpCount = pathLen = nx.shortest_path_length(fullGraph, systemNameA, systemNameB)
    return (distance, jumpCount)

(distance, jumpCount) = SystemDistance("QJ-149", "SE-110")
print("Distance: " + str(distance) + " parsecs. Jumps: " + str(jumpCount))
# Out:
# Distance: 277.5072213919227 parsecs. Jumps: 4

# %%
MaxGatewayDistance = 300
allRelevantSystems = FilterByFunction(filterCloserToANT).nodes
# bestPairs = []

# for sys1 in allRelevantSystems:
#     for sys2 in allRelevantSystems:
#         (distance, jumpCount) = SystemDistance(sys1, sys2, 1, MaxGatewayDistance)
#         if(jumpCount >= 0):
#             bestPairs.append( (distance, jumpCount, sys1 + " to " + sys2) )
#             print(sys1 + " to " + sys2 + "  Distance: " + str(distance) + " Jumps: " + str(jumpCount))
# #             print("Pair count: " + str(len(bestPairs)))
            
# #         if(len(bestPairs)> 5):
# #             break
# #     else:
# #         continue
# #     break
            
# sorted(
#     bestPairs, 
#     key=lambda x: -x[1]
# )

# %%
len(allRelevantSystems)**2
# Out:
# 51076

# %%
# %%time

x = df["PositionX"].to_numpy()
y = df["PositionY"].to_numpy()
z = df["PositionZ"].to_numpy()
names = df["Name"].to_numpy()

# Calculate pairwise distances using broadcasting
distances = np.sqrt((x[:, np.newaxis] - x[np.newaxis, :]) ** 2 +
                    (y[:, np.newaxis] - y[np.newaxis, :]) ** 2 +
                    (z[:, np.newaxis] - z[np.newaxis, :]) ** 2)

print(f"Numpy array shape: {distances.shape}")

MAX_DISTANCE_IN_PARSECS = 25.0
# Get the indices of the distances that are > 0 and < 300
indices = np.where((distances > 0) & (distances < (MAX_DISTANCE_IN_PARSECS * 12.0) ))

# Extract the pairs of indices
pairs = list(zip(indices[0], indices[1]))

print(f"Gateways Systems Matching criteria: {len(pairs)} of {len(distances)**2}. ")
# Out:
# Numpy array shape: (637, 637)
# Gateways Systems Matching criteria: 22584 of 405769.
# CPU times: total: 0 ns
# Wall time: 12.2 ms

# %%
#find best gateway locations from any system to any other system.

# Define the namedtuple
Record = namedtuple('Record', ['name1', 'name2', 'distance', 'jumpCount', 'regionPair'])
output = []

for index1, index2 in pairs:
    systemNameA = names[index1]
    systemNameB = names[index2]
    if(systemNameA > systemNameB):
        regionPair = systemNameB[:2] + systemNameA[:2]
    else:
        regionPair = systemNameA[:2] + systemNameB[:2]

    j = nx.shortest_path_length(fullGraph, systemNameA, systemNameB)
    
    r = Record(name1 = systemNameA, name2 = systemNameB, distance = distances[index1, index2], jumpCount = j, regionPair = regionPair)
    output.append(r)

# Sort the output by jumpCount in descending order
sorted_output = sorted(output, key=lambda record: record.jumpCount, reverse=True)

# Take the top 100 records
top_100_records = sorted_output[:1000]

regionPairs = []
bestRecords = []
graphPairs = []

for record in top_100_records:
    if(record.regionPair in regionPairs):
        continue
    regionPairs.append(record.regionPair)
    print(f"{record.name1} to {record.name2} saves {record.jumpCount} jumps over distance { (record.distance / 12.0):.1f} parsecs.")
    bestRecords.append(record)
    graphPairs.append( (record.name1, record.name2) )
# Out:
# OY-661 to MG-885 saves 31 jumps over distance 16.7 parsecs.
# YW-310 to MG-885 saves 28 jumps over distance 22.3 parsecs.
# NG-574 to VB-576 saves 23 jumps over distance 24.1 parsecs.
# YW-650 to OE-563 saves 23 jumps over distance 24.4 parsecs.
# NG-574 to IV-876 saves 21 jumps over distance 24.9 parsecs.
# IY-112 to AM-429 saves 20 jumps over distance 19.1 parsecs.
# PG-971 to XV-374 saves 20 jumps over distance 23.9 parsecs.
# NG-574 to AS-479 saves 19 jumps over distance 16.3 parsecs.
# NG-574 to OS-053 saves 19 jumps over distance 22.6 parsecs.
# GY-135 to OP-630 saves 19 jumps over distance 19.9 parsecs.
# IY-387 to YW-310 saves 19 jumps over distance 21.7 parsecs.
# SL-132 to SO-838 saves 18 jumps over distance 23.4 parsecs.
# HM-910 to IY-112 saves 18 jumps over distance 23.4 parsecs.
# IY-112 to Arclight saves 18 jumps over distance 20.1 parsecs.
# AS-479 to YV-599 saves 17 jumps over distance 17.3 parsecs.
# IY-112 to Mount Olympus saves 17 jumps over distance 17.9 parsecs.
# OS-053 to YV-599 saves 17 jumps over distance 24.4 parsecs.
# OF-732 to SO-245 saves 17 jumps over distance 23.1 parsecs.
# IZ-257 to PG-241 saves 17 jumps over distance 17.9 parsecs.
# KQ-205 to LG-672 saves 16 jumps over distance 22.4 parsecs.
# GY-135 to QQ-033 saves 16 jumps over distance 20.5 parsecs.
# KQ-833 to GK-115 saves 16 jumps over distance 25.0 parsecs.
# GY-135 to DW-419 saves 15 jumps over distance 24.4 parsecs.
# Gateway to IY-112 saves 15 jumps over distance 21.7 parsecs.
# OS-456 to BS-865 saves 15 jumps over distance 23.2 parsecs.
# OY-701 to XG-452 saves 15 jumps over distance 18.5 parsecs.
# OP-630 to OF-586 saves 15 jumps over distance 18.3 parsecs.
# OP-630 to AW-284 saves 15 jumps over distance 23.5 parsecs.
# YK-715 to AM-429 saves 15 jumps over distance 24.1 parsecs.
# JS-869 to HV-512 saves 15 jumps over distance 24.3 parsecs.
# Trinity to SO-028 saves 15 jumps over distance 23.8 parsecs.
# XH-668 to PD-754 saves 14 jumps over distance 23.6 parsecs.
# HM-910 to SO-245 saves 14 jumps over distance 24.9 parsecs.
# HM-910 to YK-266 saves 14 jumps over distance 21.0 parsecs.
# WB-948 to OY-701 saves 14 jumps over distance 18.6 parsecs.
# OP-630 to NL-983 saves 14 jumps over distance 19.1 parsecs.
# Outer Heaven to IZ-257 saves 14 jumps over distance 20.4 parsecs.
# QV-783 to PG-241 saves 14 jumps over distance 23.9 parsecs.
# Arclight to YK-266 saves 14 jumps over distance 22.9 parsecs.
# KW-626 to OF-208 saves 13 jumps over distance 24.7 parsecs.
# KW-626 to PD-754 saves 13 jumps over distance 21.2 parsecs.
# RC-323 to OY-701 saves 13 jumps over distance 22.1 parsecs.
# Hotei to YI-705 saves 13 jumps over distance 24.7 parsecs.
# OY-701 to Bastion saves 13 jumps over distance 17.9 parsecs.
# OY-701 to PG-710 saves 13 jumps over distance 20.8 parsecs.
# JS-009 to QR-971 saves 13 jumps over distance 24.4 parsecs.
# Mount Olympus to YK-266 saves 13 jumps over distance 19.6 parsecs.
# KQ-205 to FK-037 saves 12 jumps over distance 24.4 parsecs.
# LB-476 to GY-135 saves 12 jumps over distance 19.7 parsecs.
# QV-420 to YA-471 saves 12 jumps over distance 24.3 parsecs.
# KC-832 to LG-672 saves 12 jumps over distance 23.5 parsecs.
# Hotei to WB-948 saves 12 jumps over distance 21.7 parsecs.
# YP-819 to GC-025 saves 12 jumps over distance 24.3 parsecs.
# UQ-010 to DC-724 saves 12 jumps over distance 22.5 parsecs.
# NJ-438 to KQ-833 saves 12 jumps over distance 22.4 parsecs.
# EX-326 to FA-035 saves 12 jumps over distance 23.6 parsecs.
# JS-869 to EY-577 saves 12 jumps over distance 17.8 parsecs.
# XH-807 to OF-208 saves 12 jumps over distance 23.4 parsecs.
# Daikoku to YI-683 saves 12 jumps over distance 24.8 parsecs.
# OF-732 to JS-570 saves 12 jumps over distance 24.0 parsecs.
# TD-152 to IZ-257 saves 12 jumps over distance 18.5 parsecs.
# AU-522 to NJ-874 saves 11 jumps over distance 23.1 parsecs.
# GY-135 to UB-808 saves 11 jumps over distance 22.5 parsecs.
# Gateway to SO-245 saves 11 jumps over distance 24.2 parsecs.
# Gateway to YK-266 saves 11 jumps over distance 18.7 parsecs.
# IZ-654 to EX-326 saves 11 jumps over distance 24.5 parsecs.
# IC-945 to VI-429 saves 11 jumps over distance 24.6 parsecs.
# WU-504 to GM-498 saves 11 jumps over distance 22.0 parsecs.
# OY-661 to UQ-010 saves 11 jumps over distance 22.0 parsecs.
# OY-036 to Outer Heaven saves 11 jumps over distance 23.3 parsecs.
# CB-276 to OF-363 saves 11 jumps over distance 25.0 parsecs.
# HM-910 to LS-828 saves 11 jumps over distance 23.3 parsecs.
# HM-910 to LE-137 saves 11 jumps over distance 24.4 parsecs.
# WB-948 to FW-129 saves 11 jumps over distance 21.2 parsecs.
# OS-099 to BI-500 saves 11 jumps over distance 21.4 parsecs.
# OP-630 to OZ-189 saves 11 jumps over distance 23.0 parsecs.
# YP-278 to Cayman Planets saves 11 jumps over distance 24.9 parsecs.
# JP-324 to EY-577 saves 11 jumps over distance 25.0 parsecs.
# RG-716 to EX-326 saves 11 jumps over distance 20.5 parsecs.
# XG-452 to YI-265 saves 11 jumps over distance 22.0 parsecs.
# KC-421 to QR-971 saves 11 jumps over distance 24.2 parsecs.
# Outer Heaven to QV-783 saves 11 jumps over distance 24.1 parsecs.
# EY-363 to VH-503 saves 11 jumps over distance 24.3 parsecs.
# UY-408 to PG-710 saves 11 jumps over distance 20.0 parsecs.
# UY-408 to WB-947 saves 11 jumps over distance 22.4 parsecs.
# PD-518 to Antares I saves 11 jumps over distance 24.3 parsecs.
# Forge-Keep to EY-577 saves 11 jumps over distance 23.0 parsecs.
# KC-424 to YV-599 saves 11 jumps over distance 23.4 parsecs.
# OF-586 to QQ-033 saves 11 jumps over distance 18.6 parsecs.
# RC-040 to YI-265 saves 11 jumps over distance 23.7 parsecs.
# BS-409 to GM-332 saves 11 jumps over distance 24.6 parsecs.
# YP-951 to XV-825 saves 11 jumps over distance 23.2 parsecs.
# OP-649 to YP-916 saves 11 jumps over distance 19.6 parsecs.
# QR-646 to AJ-135 saves 11 jumps over distance 24.5 parsecs.
# UV-234 to YI-683 saves 11 jumps over distance 20.5 parsecs.
# Hubur to IZ-257 saves 11 jumps over distance 24.1 parsecs.
# UP-573 to PG-710 saves 10 jumps over distance 23.1 parsecs.
# GY-135 to PD-718 saves 10 jumps over distance 21.5 parsecs.
# GY-135 to BS-788 saves 10 jumps over distance 24.2 parsecs.
# TD-228 to OY-036 saves 10 jumps over distance 24.4 parsecs.
# XU-100 to FA-042 saves 10 jumps over distance 22.2 parsecs.
# DW-419 to OF-586 saves 10 jumps over distance 23.2 parsecs.
# XH-265 to IA-982 saves 10 jumps over distance 23.2 parsecs.
# WU-504 to AU-130 saves 10 jumps over distance 16.7 parsecs.
# IZ-816 to YA-471 saves 10 jumps over distance 23.9 parsecs.
# UP-102 to RY-780 saves 10 jumps over distance 21.6 parsecs.
# RC-323 to FW-129 saves 10 jumps over distance 19.5 parsecs.
# RC-323 to CH-364 saves 10 jumps over distance 23.4 parsecs.
# VH-241 to AJ-135 saves 10 jumps over distance 22.9 parsecs.
# OY-036 to PB-132 saves 10 jumps over distance 19.2 parsecs.
# XG-751 to XV-158 saves 10 jumps over distance 19.2 parsecs.
# Hotei to RC-639 saves 10 jumps over distance 14.8 parsecs.
# Hotei to CH-364 saves 10 jumps over distance 24.7 parsecs.
# LG-150 to EX-183 saves 10 jumps over distance 23.8 parsecs.
# Neo Eden to YK-266 saves 10 jumps over distance 23.7 parsecs.
# XH-329 to YI-683 saves 10 jumps over distance 20.7 parsecs.
# LS-231 to PD-754 saves 10 jumps over distance 23.4 parsecs.
# JS-761 to RC-659 saves 10 jumps over distance 22.3 parsecs.
# YI-059 to OY-701 saves 10 jumps over distance 17.9 parsecs.
# HM-910 to Benten saves 10 jumps over distance 23.0 parsecs.
# WB-948 to UV-062 saves 10 jumps over distance 21.0 parsecs.
# WB-948 to YI-265 saves 10 jumps over distance 13.3 parsecs.
# AW-006 to VH-778 saves 10 jumps over distance 24.8 parsecs.
# GY-919 to NL-983 saves 10 jumps over distance 23.3 parsecs.
# OP-630 to LB-056 saves 10 jumps over distance 22.5 parsecs.

# %%
#find best gateway locations ANT

# Define the namedtuple
Record = namedtuple('Record', ['name1', 'name2', 'distance', 'jumpCount', 'regionPair'])
output = []

for index1, index2 in pairs:
    systemNameA = names[index1]
    
    if(systemNameA != "Antares I" and systemNameA != "OS-099" ):
        continue
    
    systemNameB = names[index2]
    if(systemNameA > systemNameB):
        regionPair = systemNameB[:2] + systemNameA[:2]
    else:
        regionPair = systemNameA[:2] + systemNameB[:2]

    j = nx.shortest_path_length(fullGraph, systemNameA, systemNameB)
    
    r = Record(name1 = systemNameA, name2 = systemNameB, distance = distances[index1, index2], jumpCount = j, regionPair = regionPair)
    output.append(r)

# Sort the output by jumpCount in descending order
sorted_output = sorted(output, key=lambda record: record.jumpCount, reverse=True)

# Take the top 100 records
top_100_records = sorted_output[:20]

regionPairs = []
bestRecords = []
graphPairs = []

for record in top_100_records:
    if(record.regionPair in regionPairs):
        continue
    regionPairs.append(record.regionPair)
    print(f"{record.name1} to {record.name2} saves {record.jumpCount} jumps over distance { (record.distance / 12.0):.1f} parsecs.")
    bestRecords.append(record)
    graphPairs.append( (record.name1, record.name2) )
# Out:
#   Cell In[56], line 10
#     if(systemNameA != "Antares I" && systemNameA != "OS-099" ):
#                                    ^
# SyntaxError: invalid syntax

# %%
def DrawFertileButWithGatewayEdges(G, pos):
    
    color_map = "inferno"
    # draw extra nodes to create outlines and dots inside our real nodes.
    matchingKeys = [k for k,v in planet_fertile.items() if float(v) >= 1]
    f1 = intersection(G.nodes, list(matchingKeys))
    nx.draw_networkx_nodes(G, pos, node_size=300, node_color='#00FF00', nodelist=f1)

    f1 = intersection(G.nodes, list(planet_habitable.keys()))
    colorListValues = [planet_habitable[k] for k in f1]
    nx.draw(G, pos, node_size=110, with_labels=False, nodelist=f1, node_color=colorListValues, cmap=color_map)

    plt.colorbar(plt.cm.ScalarMappable(cmap=color_map, norm=Normalize(0, max(colorListValues))), shrink=0.5)

    nx.draw_networkx_edges(G, pos, graphPairs, width= 4, edge_color = '#FF0000')
    
    
graph = FilterByFunction(filterAll)
PlotGraph(graph, DrawFertileButWithGatewayEdges, "Circle indicates fertile planets. Color indicates habitability.")
# Out:
# Drawing: Node count 637 edge count: 838
# C:\Users\kortham\AppData\Local\Temp\ipykernel_53584\865380558.py:13: MatplotlibDeprecationWarning: Unable to determine Axes to steal space for Colorbar. Using gca(), but will raise in the future. Either provide the *cax* argument to use as the Axes for the Colorbar, provide the *ax* argument to steal space from it, or add *mappable* to an Axes.
#   plt.colorbar(plt.cm.ScalarMappable(cmap=color_map, norm=Normalize(0, max(colorListValues))), shrink=0.5)

# %%
#find best gateway placements to shorten a path between two specified systems:

# Define the namedtuple
Record = namedtuple('Record', ['name1', 'name2', 'distance', 'jumpCount', 'regionPair'])
output = []

for index1, index2 in pairs:
    systemNameA = names[index1]
    systemNameB = names[index2]
    if(systemNameA > systemNameB):
        regionPair = systemNameB[:2] + systemNameA[:2]
    else:
        regionPair = systemNameA[:2] + systemNameB[:2]

    j = nx.shortest_path_length(fullGraph, systemNameA, systemNameB)
    
    r = Record(name1 = systemNameA, name2 = systemNameB, distance = distances[index1, index2], jumpCount = j, regionPair = regionPair)
    output.append(r)

# Sort the output by jumpCount in descending order
sorted_output = sorted(output, key=lambda record: record.jumpCount, reverse=True)

# Take the top 100 records
top_100_records = sorted_output[:500]

regionPairs = []
bestRecords = []
graphPairs = []

for record in top_100_records:
    if(record.regionPair in regionPairs):
        continue
    regionPairs.append(record.regionPair)
    print(f"{record.name1} to {record.name2} saves {record.jumpCount} jumps over { ( record.distance / 12.0 ) :.1f} parsecs.")
    bestRecords.append(record)
    graphPairs.append( (record.name1, record.name2) )
# Out:
# NG-574 to OT-364 saves 54 jumps over 206.4 parsecs.
# NG-574 to TD-331 saves 53 jumps over 195.6 parsecs.
# NG-574 to WC-788 saves 52 jumps over 196.5 parsecs.
# OT-364 to YV-599 saves 52 jumps over 203.2 parsecs.
# NG-574 to Hubur saves 51 jumps over 194.7 parsecs.
# NG-574 to PG-710 saves 51 jumps over 176.9 parsecs.
# NG-574 to DC-823 saves 51 jumps over 190.2 parsecs.
# TD-331 to YV-599 saves 51 jumps over 191.4 parsecs.
# SG-135 to OT-364 saves 51 jumps over 206.7 parsecs.
# OT-364 to QF-764 saves 51 jumps over 211.5 parsecs.
# NG-574 to Outer Heaven saves 50 jumps over 184.7 parsecs.
# NJ-874 to OT-364 saves 50 jumps over 199.4 parsecs.
# TD-331 to SG-135 saves 50 jumps over 192.1 parsecs.
# TD-331 to QF-764 saves 50 jumps over 198.3 parsecs.
# WC-788 to YV-599 saves 50 jumps over 193.1 parsecs.
# OT-364 to BS-409 saves 50 jumps over 215.9 parsecs.
# NG-574 to QV-312 saves 49 jumps over 195.0 parsecs.
# NG-574 to PB-994 saves 49 jumps over 196.5 parsecs.
# NG-574 to EL-419 saves 49 jumps over 180.7 parsecs.
# NJ-874 to TD-331 saves 49 jumps over 184.0 parsecs.
# TD-331 to BS-409 saves 49 jumps over 198.7 parsecs.
# SG-135 to WC-788 saves 49 jumps over 196.0 parsecs.
# WC-788 to QF-764 saves 49 jumps over 201.0 parsecs.
# YV-599 to Hubur saves 49 jumps over 190.7 parsecs.
# YV-599 to PG-710 saves 49 jumps over 172.7 parsecs.
# YV-599 to DC-823 saves 49 jumps over 179.9 parsecs.
# NG-574 to OY-661 saves 48 jumps over 148.1 parsecs.
